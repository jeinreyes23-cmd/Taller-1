# %%
# variables pyton 

#solicitar datos al usuario 
nombre = input("¿Cuál es tu nombre? ")
identificacion = input("¿Cuál es tu identificación? ")

#solicitar al usuario el nombre del producto 
nombre_producto = input("¿Cuál es el nombre del producto? ")
#solicitar al usuario el precio del producto 
precio_producto = float(input("¿Cuál es el precio del producto? "))

cantidad_producto = int(input("¿Cuál es la cantidad del producto? "))
total = precio_producto * cantidad_producto

# mostrar 
print ("producto :", nombre_producto)
print("precio producto", precio_producto )
print("cantidad_producto ",cantidad_producto  )
print("total a pagar", total )
# Out:
# producto : arroz
# precio producto 2000.0
# cantidad_producto  10
# total a pagar 20000.0
